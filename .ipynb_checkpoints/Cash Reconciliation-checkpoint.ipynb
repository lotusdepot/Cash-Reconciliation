# %%
# Subtype 	 Type 	 Date 	 Date 	 Sequence 	 Cashier Name 	 Custom Data 	 USD Amount 

# END_OF_SHIFT = SUM by DATE( USD Amount , Type = "END_OF_SHIFT")+ SUM by DATE (USD AMOUNT, Type = "DEPOSIT", subtype is "" (blank))
# Tills Pulled = SUM by DATE( all BLANK "" subtype, type = DISPENSE) - SUBTRACT (DISPENSE with no custom data (Need User Input))
# Total Cash Sales = End of Shift + Tills

# %%
#imports
import pandas as pd
import numpy as np

# %%
# cash_recon = pd.read_excel("May 22 Raw Cash Treez Data.xlsx",[0,1])
raw_data = pd.read_excel("May 22 Raw Cash Treez Data.xlsx",0)[["Subtype", "Type", "Datetime", "Sequence", "Cashier Name", "Custom Data", "USD Amount"]].copy()
treez_data = pd.read_excel("May 22 Raw Cash Treez Data.xlsx",1,3)[["Total Cash Sales Treez", "End Cash per Cash Control"]].copy().iloc[1: , :].reset_index()

raw_data["Date"] = pd.to_datetime(raw_data["Datetime"])

cashierlist = ["Ballesteros, Michael","MCGEE, MIKE","Hernandez, Melissa","SERENO, CLAUDIA", "SANDERS, ERNIE", "TUCCI, NICK"]

recon = pd.DataFrame(pd.Series(raw_data["Date"].dt.date.unique(),name="Date"))


# raw_data.fillna(0)

recon["End of Shift"] = 0
recon["Tills Pulled"] = 0
for index, row in raw_data.iterrows():
#     print(row["Cashier Name"])
    prev = recon.loc[recon.index[row["Date"].day-1], "End of Shift"]
    dollars = [0 if np.isnan(row["USD Amount"]) else float(row["USD Amount"])][0]
#     print(dollars)

    #End of Shift calculation
    if row["Type"]=="END_OF_SHIFT":
        recon.loc[recon.index[row["Date"].day-1], "End of Shift"] = float(prev) + dollars
    if row["Type"]=="DEPOSIT" and not isinstance(row["Subtype"], str):
        recon.loc[recon.index[row["Date"].day-1], "End of Shift"] = float(prev) + dollars
    
    prev = recon.loc[recon.index[row["Date"].day-1], "Tills Pulled"]
    USDList = [-400, -174, -225]
    #Tills Pulled calculation
    if row["Type"]=="DISPENSE" and not isinstance(row["Subtype"], str):
        if not(row["Custom Data"]=="{}" and row["Cashier Name"] in cashierlist):
            recon.loc[recon.index[row["Date"].day-1], "Tills Pulled"] = float(prev) + dollars
        else:
            if row["Cashier Name"] == "SERENO, CLAUDIA" and row["USD Amount"] in USDList:
                recon.loc[recon.index[row["Date"].day-1], "Tills Pulled"] = float(prev) + dollars
                
recon["Total Cash Sales"] = recon["End of Shift"] + recon["Tills Pulled"]
    
recon = pd.concat([recon, treez_data["Total Cash Sales Treez"]], axis=1)
# recon.drop('index', inplace=True, axis=1)
recon = recon.set_index("Date")
recon['TCS Variance'] = (recon['Total Cash Sales'] - recon['Total Cash Sales Treez']).round(2)
# recon['TCS Variance']
# for index, row in recon.iloc[:, [2, 3]]:
#     index 

    
    
display(recon)
# raw_data.to_csv("May 2022 CashReconScript Export.csv")
# Out:
# C:\Users\dipam\AppData\Local\Temp/ipykernel_22440/2853192487.py:3: FutureWarning: Starting with pandas version 2.0 all arguments of read_excel except for the arguments 'io' and 'sheet_name' will be keyword-only
#   treez_data = pd.read_excel("May 22 Raw Cash Treez Data.xlsx",1,3)[["Total Cash Sales Treez", "End Cash per Cash Control"]].copy().iloc[1: , :].reset_index()
#             End of Shift  Tills Pulled  Total Cash Sales  \
# Date
# 2022-05-01      54000.18      -6565.00          47435.18
# 2022-05-02      57151.65      -7780.00          49371.65
# 2022-05-03      56106.17      -6565.00          49541.17
# 2022-05-04      55071.10      -5765.00          49306.10
# 2022-05-05      60924.46      -5750.00          55174.46
# 2022-05-06      77089.53      -6965.00          70124.53
# 2022-05-07      59054.87      -6335.00          52719.87
# 2022-05-08      58952.96      -6175.00          52777.96
# 2022-05-09      54869.72      -6165.00          48704.72
# 2022-05-10      53471.07      -6983.00          46488.07
# 2022-05-11      56081.20      -6379.95          49701.25
# 2022-05-13      69083.70      -7450.00          61633.70
# 2022-05-12      92789.38      -8135.00          84654.38
# 2022-05-14      62850.44      -7850.00          55000.44
# 2022-05-15      56580.65      -6310.00          50270.65
# 2022-05-16      55425.33      -6250.00          49175.33
# 2022-05-17      55238.33      -7850.00          47388.33
# 2022-05-18      45480.21      -6665.00          38815.21
# 2022-05-19      58571.73      -6655.00          51916.73
# 2022-05-20      72579.45      -7090.00          65489.45
# 2022-05-21      65687.39      -7049.00          58638.39
# 2022-05-22      56550.56      -6665.00          49885.56
# 2022-05-23      49536.80      -6245.75          43291.05
# 2022-05-24      54477.42      -7541.84          46935.58
# 2022-05-25      57287.64      -6661.08          50626.56
# 2022-05-26      63574.50      -6995.00          56579.50
# 2022-05-27      70832.76      -7487.85          63344.91
# 2022-05-28      63501.53      -7465.00          56036.53
# 2022-05-29      61169.05      -6895.00          54274.05
# 2022-05-30      50729.73      -6550.00          44179.73
# 2022-05-31      49654.86      -6250.00          43404.86
#
#             Total Cash Sales Treez  TCS Variance
# Date
# 2022-05-01                47435.18          0.00
# 2022-05-02                49371.29          0.36
# 2022-05-03                49541.17          0.00
# 2022-05-04                49306.10          0.00
# 2022-05-05                55174.56         -0.10
# 2022-05-06                70124.53          0.00
# 2022-05-07                52719.87          0.00
# 2022-05-08                52777.96          0.00
# 2022-05-09                48704.72         -0.00
# 2022-05-10                46488.07          0.00
# 2022-05-11                49701.25         -0.00
# 2022-05-13                61633.70          0.00
# 2022-05-12                84088.13        566.25
# 2022-05-14                55000.44         -0.00
# 2022-05-15                50270.65         -0.00
# 2022-05-16                49175.33          0.00
# 2022-05-17                47428.33        -40.00
# 2022-05-18                42904.77      -4089.56
# 2022-05-19                51916.73         -0.00
# 2022-05-20                65467.52         21.93
# 2022-05-21                58638.39          0.00
# 2022-05-22                49885.56          0.00
# 2022-05-23                43291.05         -0.00
# 2022-05-24                46932.58          3.00
# 2022-05-25                50626.56          0.00
# 2022-05-26                56479.50        100.00
# 2022-05-27                63346.10         -1.19
# 2022-05-28                56036.53          0.00
# 2022-05-29                54274.05          0.00
# 2022-05-30                44179.73         -0.00
# 2022-05-31                43404.86         -0.00
